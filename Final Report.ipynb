# %% [markdown]
# # Those Who Choose to Churn

# %% [markdown]
# ### Today we'll explore the outcomes to why customers would churn, and not stick around. I theorize that perhaps some do not like the deals they have and changed to a either diferent contract or switched entirely, and maybe offer a solution to prevent churns for future customers. Is it because of their contract type, monthly charges, having a phone service, or how long a tenure would decide the contract? These questions shall be answered if visual graphs that shall be shown below.

# %% [markdown]
# ## We shall begin by adding important libraries and visualizations to start

# %%
from pydataset import data
import pandas as pd
import os
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings("ignore")
from prepare import telco_prep as telco
from Model import train,test

# %% [markdown]
# ### Let's find out why some customers churn

# %% [markdown]
# ## Is it becuase of their contract type?

# %%
from Model import contract_tenure_cnt

# %% [markdown]
# #### Importing the data needed to find the count of the contract types, Let's count each contract type

# %%
contract_tenure_cnt(train)

# %% [markdown]
# ### A majority of clients have taken the first type of contract, possibly being cheaper, but then you see contract 3 being almost half of it's amount, rather than getting smaller than the second contact.

# %%
from Model import churn_sctr

# %% [markdown]
# ## Is there is any correlation from a tenure length to monthly charges?

# %% [markdown]
# ### A scatterplot shall be used to find each customer's position on the length of their tenure and how much they spend before churning.

# %%
churn_sctr(train)

# %% [markdown]
# ## Most of the churns happen at the first 10 to 40 months and above the 70 dollar mark.

# %% [markdown]
# ### Now let us check is there are any utilities that may impact the churn.

# %%
from Model import phone_churn

# %% [markdown]
# ## Does having a phone in the plan influence the churning?

# %%
phone_churn(train)

# %% [markdown]
# ## There is a very large difference between those that did churn and those who didn't. Most likely they have joined to only use the service for streaming movies and videos.

# %%
from Model import contract_tenure

# %% [markdown]
# ## Does the length of the tenure can also play a part in the contract type?

# %%
contract_tenure(train)

# %% [markdown]
# ## It would appear that contract 3, despite being pricer, has the highest tenure over the other two with contract 1 having the shortest tenure, not even being half as much as contract 2.

# %% [markdown]
# # The Take Aways

# %% [markdown]
# ## It would appear that a majority of contract 1 customers tend to churn more ofter than the other two, ethier because they were trying it out for a short period or were not satisfied by what contract 1 had to offer.

# %% [markdown]
# ### One solution is to offer a bonus discount if after 6 months with no issues, the customer is offered an oprotunity to upgrade their contract to the next level for free for a month and a discount if they accept the offer.
